# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# %%
model = YOLO("yolov8n-seg.pt")  

results = model("dog.jpeg")
# Out:
# image 1/1 C:\Users\FreeComp\Downloads\Computer-Vision-main\Computer-Vision-main\Task7\Yolo_segmentation\dog.jpeg: 480x640 1 dog, 124.2ms
# Speed: 4.0ms preprocess, 124.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
