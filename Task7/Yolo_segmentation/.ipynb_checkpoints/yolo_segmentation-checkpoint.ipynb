# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO("C:/Users/it shop/Downloads/Telegram Desktop/yolov8n-seg.pt")  

results = model("E:/Senior Term1/New folder/cat.jpg")
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 6.74M/6.74M [00:26<00:00, 268kB/s]
# image 1/1 E:\Senior Term1\New folder\cat.jpg: 640x640 1 cat, 1 dog, 1247.0ms
# Speed: 46.9ms preprocess, 1247.0ms inference, 62.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
