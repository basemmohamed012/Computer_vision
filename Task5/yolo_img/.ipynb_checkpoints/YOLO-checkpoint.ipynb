# %%
 pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.39-py3-none-any.whl.metadata (35 kB)
# ...
#   Using cached torchvision-0.20.1-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# ...
#   Using cached ultralytics_thop-2.0.12-py3-none-any.whl.metadata (9.4 kB)
# ...
# Using cached ultralytics-8.3.39-py3-none-any.whl (896 kB)
# Using cached torchvision-0.20.1-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached ultralytics_thop-2.0.12-py3-none-any.whl (26 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO("C:/Users/it shop/Downloads/yolov8n.pt")
results = model(source="E:/Senior Term1/New folder/img.jpg", show=True, conf=0.4, save=True)
# Out:
# image 1/1 E:\Senior Term1\New folder\img.jpg: 640x480 8 persons, 539.9ms
# Speed: 9.5ms preprocess, 539.9ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict10

# %%
result_img = results[0].plot()  
plt.imshow(result_img)
plt.axis('off')
plt.show()
